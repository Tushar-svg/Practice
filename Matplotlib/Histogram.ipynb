# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data =[1,43,54,6,87,93,23,60,87,0]

# %%
plt.hist(data,bins=10)
# Out:
# (array([3., 0., 1., 0., 1., 1., 1., 0., 0., 3.]),
#  array([ 0. ,  9.3, 18.6, 27.9, 37.2, 46.5, 55.8, 65.1, 74.4, 83.7, 93. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,bins=[10,20,30,50,70,100])
# Out:
# (array([0., 1., 1., 2., 3.]),
#  array([ 10.,  20.,  30.,  50.,  70., 100.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(data,bins=10,edgecolor='black')
# Out:
# (array([3., 0., 1., 0., 1., 1., 1., 0., 0., 3.]),
#  array([ 0. ,  9.3, 18.6, 27.9, 37.2, 46.5, 55.8, 65.1, 74.4, 83.7, 93. ]),
#  <BarContainer object of 10 artists>)

# %%
ages = [
 34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
 25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
 44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
 23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
 37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
 33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
 25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
 33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
 27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
 30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]
bins = [10, 20, 30, 40, 50, 60, 70]

# %%
plt.hist(ages,bins=bins,edgecolor='black')
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.tight_layout()
plt.grid(True,linestyle='--',color='red',linewidth=0.2,alpha=0.9)
plt.show()

# %%
plt.hist(ages,bins=bins,edgecolor='black')
plt.axvline(np.mean(ages),color='white',linestyle='--',label='Average age')
plt.title('Age Distribution of YouTube Viewers')
plt.legend()
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.tight_layout()
plt.grid(True,linestyle='--',color='red',linewidth=0.2,alpha=0.9)
plt.show()
