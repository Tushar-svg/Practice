# %% [raw]
# Ques Union of two sets.
# QUES Intersection of two sets.
# QUES Difference between sets.
# QUES Check subset.                               these are easy use dir

# %% [markdown]
# Ques .) Remove duplicates from list using set.

# %%
l = [1,2,2,3,3,4,4,5] 
l2= set(l)
print(l2)
# Out:
# {1, 2, 3, 4, 5}
