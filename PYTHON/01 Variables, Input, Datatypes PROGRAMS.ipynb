# %% [markdown]
# QUES
# User se name aur age lo, print:

# %%
name = input("Enter Your Name")
age= input("Enter your age ")
print(f"Hi {name}, after 5 years you will be {int(age)+5}")
# Out:
# Enter Your Name Tushar Jangra
# Enter your age  21
# Hi Tushar Jangra, after 5 years you will be 26

# %% [markdown]
# QUES .)
# Length aur width input lo, rectangle area nikalo.

# %%
length = int(input("Enter the length"))
width = int(input("Enter the width"))
area=length * width 
print(area)
# Out:
# Enter the length 20
# Enter the width 20
# 400

# %% [markdown]
# QUES )
# Celsius input lo, Fahrenheit me convert karo.

# %%
celsius = int(input("Enter the temp. in C"))
fahrenheit = celsius * 9/5 +32
print(f"The Temperature is {celsius} in C and {fahrenheit} in F")
# Out:
# Enter the temp. in C 23
# The Temperature is 23 in C and 73.4 in F

# %% [markdown]
# Ques ) User ki salary input lo, 10% increment ke baad salary print karo.

# %%
salary = int(input("Enter your salary"))
new_salary = salary + (salary * 10 / 100)
print(f"The salary after 10% increment is {new_salary}")
# Out:
# Enter your salary 20000
# The salary after 10% increment is 22000.0
