# %% [markdown]
#  Student marks dictionary.

# %%
students = {
    "Rahul": 85,
    "Priya": 92,
    "Aman": 76,
    "Neha": 95,
    "Karan": 38
}

# %% [markdown]
# Ques Find topper.

# %%
top= max(students.values())
for name,marks in students.items():
        if top==marks:
            print(name)
# Out:
# Neha

# %% [markdown]
# Ques Calculate average marks.

# %%
avg=sum(students.values())/len(students)

# %%
avg
# Out:
# 77.2

# %% [markdown]
# Ques . find failed students (<40).

# %%
d= students.values()
for name,marks in students.items():
    if marks <40:
        print(name,marks)
# Out:
# Karan 38

# %%
text = "data science"

# %% [markdown]
# Ques . Count frequency of characters in a string.

# %%
freq={}
for char in text :
    if char == " ":
        continue
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1

print(freq)
# Out:
# {'d': 1, 'a': 2, 't': 1, 's': 1, 'c': 2, 'i': 1, 'e': 2, 'n': 1}
