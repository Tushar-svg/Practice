# %% [markdown]
# Ques .)Name reverse karo.

# %%
s= "Tushar"
print(s[::-1])
# Out:
# rahsuT

# %% [markdown]
# String me vowels count karo.

# %%
s = "Tushar"

count = 0

for ch in s:
    if ch in ["a","e","i","o","u"]:
        count += 1

print(count)

# %% [markdown]
# Ques . Check karo string palindrome hai ya nahi.

# %%
s = str(input("Enter name "))

if s[0::]==s[::-1]:
    print("True")
else:
    print("False")
# Out:
# Enter name  nitin
# True

# %% [raw]
# Ques User ka full name input lo aur initials print karo.
# Example:
# Tushar Kumar Sharma
# Output:
# TKS

# %%
name = input("Enter your name: ")
parts = name.split()

initials = ""

for word in parts:
    initials += word[0]

print(initials)
# Out:
# Enter your name:  Neil Nitin Mukesh
# NNM
